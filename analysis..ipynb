# %%
#imports
import pandas as pd

# %%
nyc_data = pd.read_csv("C:/Users/Ralph Arren/Desktop/Uni/Uni Year 3/ML_Project/City_Council_Capital_Budget.csv", encoding="ISO-8859-1")
# nyc_data.head()

# %%
nyc_data.isnull().sum()
# displaying rows with missing values
# nyc_data[nyc_data.isnull().any(axis=1)]
# Out:
# Reported              0
# Fiscal_Year          12
# Borough               2
# Award                12
# Council_District     33
# Sponsor              33
# Title                 7
# Description         108
# ID                    2
# Budget_Line           3
# dtype: int64

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________
# Dealing with "Reported" column

# %%
# Cell 3: Show rows where 'Reported' is not a number
# errors='coerce' turns non-numbers into NaN, so we just look for those
nyc_data[pd.to_numeric(nyc_data['Reported'], errors='coerce').isna()]
# Out:
#                        Reported Fiscal_Year  Borough  Award Council_District  \
# 2440               BATHROOMS AT         NaN      NaN    NaN              NaN
# 2441                  PARK WEST         NaN      NaN    NaN              NaN
# 2442   HIGH SCHOOL (M535/M542)"         NaN     FY20    NaN              NaN
# 2458         GYMNASIUM UPGRADE"         NaN     FY20    NaN              NaN
# 5450             B:X546 S:X546"         NaN     FY22    NaN              NaN
# 6403             B:M028 S:M028"         NaN     FY23    NaN              NaN
# 11254         EDUCATION CENTER"         NaN  2000000    NaN              NaN
#
#       Sponsor Title Description  \
# 2440      NaN   NaN         NaN
# 2441      NaN   NaN         NaN
# 2442      NaN   NaN         NaN
# 2458      NaN   NaN         NaN
# 5450      NaN   NaN         NaN
# 6403      NaN   NaN         NaN
# 11254     NaN   NaN         NaN
#
#                                                       ID Budget_Line
# 2440                                                 NaN         NaN
# 2441                                                 NaN         NaN
# 2442   --RENOVATE A MALE AND FEMALE BATHROOM FOR NYC ...      170000
# 2458                                       ERROR: #NAME?      300000
# 5450                                       ERROR: #NAME?       55000
# 6403                                       ERROR: #NAME?      150000
# 11254                                               FY26         NaN

# %% [markdown]
# We will be dropping all 7 rows with invalid years because they are corrupted. They make up less than 5% of our data (0.06%) to be exact, so the effect is negligible. Risk is high if we keep them.
#
# (2440, 2441, 2442, 2458, 5450, 6403, 11254)

# %%
#Dropping Cells with invalid "reported" values: 

nyc_data = nyc_data[pd.to_numeric(nyc_data['Reported'], errors='coerce').notna()]

# %%
#Checking
nyc_data[pd.to_numeric(nyc_data['Reported'], errors='coerce').isna()]
# Out:
# Empty DataFrame
# Columns: [Reported, Fiscal_Year, Borough, Award, Council_District, Sponsor, Title, Description, ID, Budget_Line]
# Index: []

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# Here we handle missing or invalid Fiscal_Years

# %%
# Create a filter for rows where Fiscal_Year is null (NaN)
missing_fiscal = nyc_data[nyc_data['Fiscal_Year'].isnull()]

# Display these rows
missing_fiscal
# Out:
#       Reported Fiscal_Year Borough  Award Council_District      Sponsor  \
# 2439      2020         NaN       M    NaN                3      Johnson
# 2457      2020         NaN       K    NaN               36      Cornegy
# 5449      2022         NaN       M    NaN               10    Rodriguez
# 6402      2023         NaN       M    NaN                7        Abreu
# 11253     2026         NaN       Q    NaN               23  Speaker,Lee
#
#                                        Title                    Description  \
# 2439                         MORE ACCESSIBLE                            NaN
# 2457    P.S. 3 BEDFORD VILLAGE (K003) (K003)                            NaN
# 5449              BRONX  THEATRE HIGH SCHOOL                            NaN
# 6402   P.S. 28 - AUDITORIUM LIGHTING UPGRADE                            NaN
# 11253  QUEENS COUNTY FARM EDUCATIONAL CENTER  CONSTRUCTION OF A VISITOR AND
#
#              ID Budget_Line
# 2439   E  CN817     E  D001
# 2457   E  CN832     E  D001
# 5449   E  CN673     E  D001
# 6402   E  CN136     E  D001
# 11253  P CN1606      P D019

# %%
valid_format = r'^FY\d{2}$'
is_invalid = ~nyc_data['Fiscal_Year'].str.match(valid_format, na=False) & nyc_data['Fiscal_Year'].notna()
nyc_data[is_invalid]
# Out:
# Empty DataFrame
# Columns: [Reported, Fiscal_Year, Borough, Award, Council_District, Sponsor, Title, Description, ID, Budget_Line]
# Index: []

# %% [markdown]
# No invalid Fiscal_Year entries

# %%
nyc_data['Fiscal_Year'] = nyc_data['Fiscal_Year'].ffill()

# %%
#check
nyc_data[nyc_data['Fiscal_Year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Reported, Fiscal_Year, Borough, Award, Council_District, Sponsor, Title, Description, ID, Budget_Line]
# Index: []

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________
# Dealing with Boroughs
# Valid Borough Values: 'M', 'X', 'K', 'Q', 'R'
# (S and SI is for Staten Island, which is not present in this data set)
#
# M - Manhattan,
# X - The Bronx,
# K - Brooklyn (Kings),
# Q - Queens,
# R - Staten Island (Richmond),

# %%
nyc_data['Borough'].value_counts()
# Out:
# Borough
# Q    3106
# K    2955
# M    2756
# X    1852
# R     781
# A      45
# C       1
# Name: count, dtype: int64

# %%
# Cell 4: Show rows with weird Borough codes
valid_boroughs = ['M', 'X', 'K', 'Q', 'R', 'A'] 
#A most-likely stands for Citywide (we will drop this later on)
#S and SI is for Staten Island, which is not present in this data set
nyc_data[~nyc_data['Borough'].isin(valid_boroughs) & nyc_data['Borough'].notna()]
# Out:
#      Reported Fiscal_Year Borough      Award Council_District  \
# 2732     2020        FY20       C  3000000.0               15
#
#               Sponsor                   Title  \
# 2732  Speaker, Torres  CONCOURSE VILLAGE, INC
#
#                                             Description        ID Budget_Line
# 2732  FUNDS WILL SUPPORT NEEDED REPAIRS AT THE DEVEL...  HD NC926     HD D003

# %%
#Changing the "C" Borough value to "X" since CONCOURSE VILLAGE, INC is locatd in the South Brox
nyc_data.loc[2732, 'Borough'] = 'X'

# %%
#checking value
nyc_data.loc[2732, 'Borough']
# Out:
# 'X'

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________
# Dealing with 'Council_District' values

# %%
# Cell 5: Filter for any invalid District numbers
nyc_data[pd.to_numeric(nyc_data['Council_District'], errors='coerce').isna()]
# Out:
#      Reported Fiscal_Year Borough      Award Council_District Sponsor  \
# 3300     2021        FY21       A   504000.0              NaN     NaN
# 4188     2021        FY21       A   277000.0              NaN     NaN
# 4311     2021        FY21       A  2800000.0              NaN     NaN
# 4345     2021        FY21       A   514000.0              NaN     NaN
# 4346     2021        FY21       A   377000.0              NaN     NaN
# 4384     2021        FY21       A   490000.0              NaN     NaN
# 4416     2021        FY21       A  2973000.0              NaN     NaN
# 4481     2021        FY21       A   500000.0              NaN     NaN
# 4580     2021        FY21       A  1915000.0              NaN     NaN
# 4706     2021        FY21       A   150000.0              NaN     NaN
# 4770     2021        FY21       A    59000.0              NaN     NaN
# 7170     2023        FY23       M   500000.0              NaN     NaN
# 7171     2023        FY23       K  1000000.0              NaN     NaN
# 7172     2023        FY23       K    55000.0              NaN     NaN
# 7215     2023        FY23       A   100000.0              NaN     NaN
# 7216     2023        FY23       A  2681000.0              NaN     NaN
# 7217     2023        FY23       K   200000.0              NaN     NaN
# 7270     2023        FY23       A  4280000.0              NaN     NaN
# 7271     2023        FY23       Q  2811000.0              NaN     NaN
# 7300     2023        FY23       K   299000.0              NaN     NaN
# 7362     2023        FY23       K   782000.0              NaN     NaN
# 7598     2023        FY23       Q   250000.0              NaN     NaN
# 7599     2023        FY23       M   500000.0              NaN     NaN
# 7600     2023        FY23       K  1500000.0              NaN     NaN
# 7609     2023        FY23       A    75000.0              NaN     NaN
# 7677     2023        FY23       K  7600000.0              NaN     NaN
#
#                                                   Title  \
# 3300  JEWISH CHILD CARE ASSOCIATION OF NEW YORK - IN...
# 4188                MAKE THE ROAD NEW YORK CONSTRUCTION
# 4311                             VILLA MARIA REHAB WORK
# 4345    NEWYORK-PRESBYTERIAN QUEENS ULTRASOUND MACHINES
# 4346  FLUSHING HOSPITAL - MOMMOGRAPHY AND ULTRASOUND...
# 4384  CUNY CITY TECH PEARL BUILDING 3RD FLOOR CONSTR...
# 4416  GREENBURGER CENTER FOR SOCIAL AND CRIMINAL JUS...
# 4481              ST. ALBANS RENOVATION (850 LQSARENOV)
# 4580                      DETECTIVE KEITH WILLIAMS PARK
# 4706          ABC NO RIO - CONSTRUCTION OF NEW FACILITY
# 4770         PROJECT RENEWAL INITIAL OUTFITTING PROJECT
# 7170  P.S. 290M ROOFTOP PLAY YARD CONVERSION (B:M190...
# 7171                     PS 346 - LIBRARY B:K346 S:K452
# 7172        P.S. 66 - LAPTOP CARTS SYSTEM B:K066 S:K771
# 7215                           NYCHA MARBLE HILL HOUSES
# 7216                                       SMITH HOUSES
# 7217  NYCHA LONG ISLAND BAPTIST HOUSES ENTRYWAY & EX...
# 7270                    CYPRESS HILLS CHILD CARE ASSOC.
# 7271  INDIA HOME, INC. HOUSING APPLIATION 208747291-...
# 7300              THE BROOKDALE HOSPITAL MEDICAL CENTER
# 7362                                  H+H GOTHAM HEALTH
# 7598       TRIANGLE AT SHAD CREEK RD AND CROSS BAY BLVD
# 7599  RUPPERT PARK COMFORT STATION (ADDITIONAL $3.5M...
# 7600                               DPR GRACE PLAYGROUND
# 7609  NYPD CAMERAS FOR 168TH STREET BETWEEN CLAY AVE...
# 7677  THE CAMPAIGN AGAINST HUNGER FOOD HUB (20-09348...
#
#                                             Description        ID Budget_Line
# 3300  REALLOCATION OF PRIOR FUNDING IN THREE PROJECT...  CS TA001    CS DN207
# 4188  REALLOCATION OF PRIOR FUNDING IN 850 ROADNYC2 ...  ED TA001    ED DN631
# 4311  REALLOCATION OF FUNDING FROM 806 RLAFMOR LAFAY...  HD TA001     HD D024
# 4345  REALLOCATION OF PRIOR FUNDING FROM 850 HLDNHOS...  HL TA001    HL DN305
# 4346  REALLOCATION OF PRIOR FUNDING IN 850 HLDNFLUSH...  HL TA002    HL DN565
# 4384  REALLOCATION OF FUNDING FROM ACADEMIC LEARNING...  HN TA001     HN D300
# 4416  REALLOCATION OF PRIOR FUNDING FROM EXISTING PR...  HR TA001    HR DN01N
# 4481  REALLOCATION OF FUNDING FROM SOUTH HOLLIS LIBR...  LQ TA001     LQ D122
# 4580        REALLOCATION OF FUNDING FROM 846 P-412RWP5.  P  TA001     P  D019
# 4706        REALLOCATION OF FUNDING FROM 801 GOVISSPWK.  PV TA001     PV D467
# 4770  REALLOCATION OF PRIOR FUNDING IN 850 HL99PROJR...  PW TA001    HH DN336
# 7170                                                NaN  E  RR001     E  D001
# 7171                  CREATE NEW LIBRARY AT THIS SCHOOL  E  RR002     E  D001
# 7172                             10 MOBILE LAPTOP CARTS  E  RR003     E  D001
# 7215  RESTORATION OF LAUNDRY ROOM. (FUNDING REALLOCA...  HA RR001     HA D001
# 7216  DEVELOPMENT OF COMMUNITY CENTER WITH MADISON-H...  HA RR002     HA D001
# 7217                                                NaN  HA RR003     HA D001
# 7270  DEVELOP VACANT BUILDING AT 3285 AND 3287 FULTO...  HD RR001     HD D020
# 7271  DEVELOPMENT OF A NEW 50 UNIT SUPPORTIVE/SENIOR...  HD RR002     HD D022
# 7300              11 163 17-I3919 BRACHYTHERAPY MACHINE  HL RR001    HL DN168
# 7362  REPLACEMENT LED FIXTURES, INSTALL DAYLIGHT SEN...  HO RR001     HO D003
# 7598      INSTALLATION OF PAVING AND OTHER IMPROVEMENTS  P  RR001     P  D019
# 7599                                                NaN  P  RR002     P  D018
# 7600  PHASE 2: RECONSTRUCT SITTING AREAS AND CONSTRU...  P  RR003     P  D017
# 7609  REALLOCATION OF FUNDING FROM DOT PROJECT 841 T...  PO RR001     PO D185
# 7677  ADDITIONAL FUNDING TOWARDS FOOD HUB/WAREHOUSE ...  PW RR001    PW DN03G

# %%
#conversion to numeric
nyc_data['Council_District_num'] = pd.to_numeric(
    nyc_data['Council_District'],
    errors='coerce'
)

nyc_data.loc[
    nyc_data['Council_District_num'].notna() &
    ~nyc_data['Council_District_num'].between(1, 51)
]
# Out:
#       Reported Fiscal_Year Borough      Award Council_District  \
# 875       2019        FY19       M  1000000.0             1000
# 876       2019        FY19       Q   750000.0             2800
# 878       2019        FY19       R  1500000.0           955000
# 879       2019        FY19       K  3500000.0             4700
# 880       2019        FY19       M  2000000.0             1000
# ...        ...         ...     ...        ...              ...
# 11497     2026        FY26       Q   299000.0               99
# 11498     2026        FY26       R   933000.0               99
# 11499     2026        FY26       Q   318000.0               99
# 11500     2026        FY26       M   189000.0               99
# 11501     2026        FY26       M   111000.0               99
#
#                                          Sponsor  \
# 875                           Rodriguez, Speaker
# 876                               Adams, Speaker
# 878    Staten Island Delegation, Matteo, Speaker
# 879                             Treyger, Speaker
# 880                           Rodriguez, Speaker
# ...                                          ...
# 11497                      Technical Adjustments
# 11498                      Technical Adjustments
# 11499                      Technical Adjustments
# 11500                      Technical Adjustments
# 11501                      Technical Adjustments
#
#                                                    Title  \
# 875                        GEORGE WASHINGTON HIGH SCHOOL
# 876                       HSLEPS, Q690 AUDITORUM UPGRADE
# 878                         I.S. 51 - PLAYGROUND UPGRADE
# 879    JOHN DEWEY HIGH SCHOOL (21K540) - AUDITORIUM U...
# 880               GREGORIO LUPERON H.S. ROBOTICS PROGRAM
# ...                                                  ...
# 11497             ST. MARY'S HOSPITAL INITIAL OUTFITTING
# 11498                  STATEN ISLAND UNIVERSITY HOSPITAL
# 11499  KOREAN-AMERICAN FAMILY SERVICE CENTER, INC. (8...
# 11500  CEC STUYVESANT COVE, INC. DBA SOLAR ONE (850 E...
# 11501                           PROJECT RENEWAL  VEHICLE
#
#                                              Description         ID  \
# 875                        SCIENCE LAB FOR ALL 4 SCHOOLS   E  CN881
# 876                   AUDITORIUM UPGRADE AT HSLEPS, Q690   E  CN882
# 878          PLAYGROUND  IS 51 (PRINCIPAL NICHOLAS MELE)   E  CN885
# 879                                   AUDITORIUM UPGRADE   E  CN888
# 880                                   TECHNOLOGY UPGRADE   E  CN892
# ...                                                  ...        ...
# 11497                             IO FOR NEW 18 BED UNIT  HL NC1549
# 11498                            ELECTROPHYSIOLOGY LAB 2  HL NC1550
# 11499  TECHNICAL ADJUSTMENT TO RESTORE FUNDS TO PROJE...  HR NC1552
# 11500  TECHNICAL ADJUSTMENT TO RESTORE FUNDS TO 850 E...  ED NC1553
# 11501                          MOBILE HEALTHCARE VEHICLE  HH NC1558
#
#       Budget_Line  Council_District_num
# 875       E  D001                1000.0
# 876       E  D001                2800.0
# 878       E  D001              955000.0
# 879       E  D001                4700.0
# 880       E  D001                1000.0
# ...           ...                   ...
# 11497    HL DN367                  99.0
# 11498    HL DN404                  99.0
# 11499    HR DN918                  99.0
# 11500    ED DN690                  99.0
# 11501    HH DN336                  99.0
#
# [1106 rows x 11 columns]

# %% [markdown]
# Let's drop Council_District since we dont need that anymore

# %%
# nyc_data = nyc_data.drop(columns=['Council_District'])
#check
nyc_data.head()
# Out:
#   Reported Fiscal_Year Borough      Award           Sponsor  \
# 0     2019        FY19       X   250000.0            Gibson
# 1     2019        FY19       K  3640000.0  Speaker, Espinal
# 2     2019        FY19       M   425000.0            Kallos
# 3     2019        FY19       M   100000.0            Kallos
# 4     2019        FY19       M    35000.0            Kallos
#
#                                                Title  \
# 0                              VOLUNTEERS OF AMERICA
# 1                    CYPRESS HILLS CHILD CARE CENTER
# 2  [SCA] [02M077/02M198] LOWER LAB/ISADOR E. IDA ...
# 3  [SCA] [02M077/02M198] LOWER LAB/ISADOR E. IDA ...
# 4             [SCA] [02M114] EAST SIDE MIDDLE SCHOOL
#
#                              Description        ID Budget_Line  \
# 0  CLARKE PLACE SENIOR RESIDENCE PROJECT  AG CN002     HD D024
# 1    CONSTRUCTION OF A CHILD CARE CENTER  CS NC001    CS DN956
# 2              HVAC SYSTEM FOR CAFETERIA  E  CN001     E  D001
# 3                  PLAYGROUND RENOVATION  E  CN002     E  D001
# 4                    TECHNOLOGY UPGRADES  E  CN003     E  D001
#
#    Council_District_num
# 0                  16.0
# 1                  37.0
# 2                   5.0
# 3                   5.0
# 4                   5.0

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________
# Dropping more colums we generally do not need!
#
# - Reported [DROPPED] : redundant with fiscal year, and could reduce accuracy. Fiscal Year is more important as it gives us information of when the money was actually allocated to a project.
#
# - ID [DROPPED] : unique keys have no predictive power.
#
# - Sponsor : text ver of council_district, redundant

# %%
# nyc_data = nyc_data.drop(columns=['Reported', 'ID'])
nyc_data = nyc_data.drop(columns='Sponsor')
#check
nyc_data.head()
# Out:
#   Fiscal_Year Borough      Award  \
# 0        FY19       X   250000.0
# 1        FY19       K  3640000.0
# 2        FY19       M   425000.0
# 3        FY19       M   100000.0
# 4        FY19       M    35000.0
#
#                                                Title  \
# 0                              VOLUNTEERS OF AMERICA
# 1                    CYPRESS HILLS CHILD CARE CENTER
# 2  [SCA] [02M077/02M198] LOWER LAB/ISADOR E. IDA ...
# 3  [SCA] [02M077/02M198] LOWER LAB/ISADOR E. IDA ...
# 4             [SCA] [02M114] EAST SIDE MIDDLE SCHOOL
#
#                              Description Budget_Line  Council_District_num
# 0  CLARKE PLACE SENIOR RESIDENCE PROJECT     HD D024                  16.0
# 1    CONSTRUCTION OF A CHILD CARE CENTER    CS DN956                  37.0
# 2              HVAC SYSTEM FOR CAFETERIA     E  D001                   5.0
# 3                  PLAYGROUND RENOVATION     E  D001                   5.0
# 4                    TECHNOLOGY UPGRADES     E  D001                   5.0

# %% [markdown]
# Data Cleaning Part 2____________________________________________________________________________________________________________________________
# checking for any null and invalid entries per column

# %%
nyc_data.isnull().sum()
# Out:
# Fiscal_Year               0
# Borough                   0
# Award                     5
# Title                     0
# Description             101
# Budget_Line               0
# Council_District_num     26
# dtype: int64

# %%
#Drop the 5 rows where Award is null
nyc_data.dropna(subset=['Award'], inplace = True)

#check
nyc_data.isnull().sum()
# Out:
# Fiscal_Year              0
# Borough                  0
# Award                    0
# Title                    0
# Description             97
# Budget_Line              0
# Council_District_num    26
# dtype: int64

# %%
#Dealing with Awards
nyc_data[pd.to_numeric(nyc_data['Award'], errors='coerce').isna()]
# Out:
# Empty DataFrame
# Columns: [Fiscal_Year, Borough, Award, Title, Description, Budget_Line, Council_District_num]
# Index: []

# %%
nyc_data[nyc_data['Award'].astype(str).str.contains('$', regex=False)]
# Out:
# Empty DataFrame
# Columns: [Fiscal_Year, Borough, Award, Title, Description, Budget_Line, Council_District_num]
# Index: []

# %% [markdown]
# Everything looks consistent so far...let's export

# %%
# nyc_data.to_csv('cleaned_nyc_capital_projects.csv', index=False)

# %%
nyc_data.shape
# Out:
# (11491, 7)
